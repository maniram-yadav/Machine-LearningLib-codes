# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.cross_validation import train_test_split
from sklearn import preprocessing
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
data=pd.read_csv("/home/maniram/data/bank.csv",header=0)

# %%
data.shape
# Out:
# (7945, 21)

# %%
print(list(data.columns))
# Out:
# ['age', 'job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays', 'previous', 'poutcome', 'emp_var_rate', 'cons_price_idx', 'cons_conf_idx', 'euribor3m', 'nr_employed', 'y']

# %%
plt.rc("font",size=15)
sns.set(style='white')
sns.set(style='darkgrid',color_codes=True)
sns.countplot(x='y',data=data,palette="hls")
plt.show()

# %%
subscribed=len(list(data['y']==1.0))
unsubscribed=len(list(data['y']==0.0))
total=subscribed+unsubscribed
print(subscribed)
print(unsubscribed)
print(total)
print(data.shape[0])
#data['y'].count_values(dropna=false)
type(data)
data['y'].value_counts().plot.barh()
plt.show()
data.isnull().sum()
# Out:
# 7945
# 7945
# 15890
# 7945
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp_var_rate      0
# cons_price_idx    1
# cons_conf_idx     1
# euribor3m         1
# nr_employed       1
# y                 1
# dtype: int64

# %%
sns.countplot(y='job',data=data)
plt.show()
sns.countplot(y='education',data=data)
plt.show()
sns.countplot(y='marital',data=data)
plt.show()
sns.set(style="whitegrid")
sns.countplot(y='loan',data=data)
plt.show()
sns.countplot(y='default',data=data)
plt.show()

#'age', 'job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays', 'previous', 'poutcome', 'emp_var_rate', 'cons_price_idx', 'cons_conf_idx', 'euribor3m', 'nr_employed', 'y

# %%
#data.drop(data.columns[[0, 3,  8, 9, 10, 11, 12, 13, 15, 16, 17, 18, 19]], axis=1, inplace=True)
data2 = pd.get_dummies(data, columns =['job', 'marital', 'default', 'housing', 'loan', 'poutcome'])
# data2.drop(data2.columns[[12, 16, 18, 21, 24]], axis=1, inplace=True)
print(data2.shape)
print(data.columns)
print(data.columns.size)
sns.heatmap(data2.corr())
plt.show()


X = data2.iloc[:,1:]
y = data2.iloc[:,0]
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)
# Out:
# (7945, 29)
# Index(['job', 'marital', 'default', 'housing', 'loan', 'poutcome', 'y'], dtype='object')
# 7

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,y,random_state=0)
lrg = LogisticRegression(random_state=0)
lrg.fit(X_train,Y_train)
Y_pred = lrg.predict(X_test)
print(Y_pred)
# Out:
# [ 0.  0.  0. ...,  0.  0.  0.]
