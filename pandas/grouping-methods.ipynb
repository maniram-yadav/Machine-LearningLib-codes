# %%
import numpy as np
import pandas as pd

# %%
gm = pd.read_csv('../datas/gapminder.tsv', sep='\t')

# %%
gm.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
gm.groupby('continent')['pop'].mean()
# Out:
# continent
# Africa      9.916003e+06
# Americas    2.450479e+07
# Asia        7.703872e+07
# Europe      1.716976e+07
# Oceania     8.874672e+06
# Name: pop, dtype: float64

# %%
grpcnt=gm.groupby('continent')['pop'].agg(np.sum)
grpcnt
# Out:
# continent
# Africa       6187585961
# Americas     7351438499
# Asia        30507333901
# Europe       6181115304
# Oceania       212992136
# Name: pop, dtype: int64

# %%
yr1957=gm.loc[gm['year']==1957,:]
yr1957.head()
# Out:
#         country continent  year  lifeExp       pop    gdpPercap
# 1   Afghanistan      Asia  1957   30.332   9240934   820.853030
# 13      Albania    Europe  1957   59.280   1476505  1942.284244
# 25      Algeria    Africa  1957   45.685  10270856  3013.976023
# 37       Angola    Africa  1957   31.999   4561361  3827.940465
# 49    Argentina  Americas  1957   64.399  19610538  6856.856212

# %%
yr1957['lifeExp'].agg(np.mean)
# Out:
# 51.50740112676054

# %%
yr1957['lifeExp'].agg(np.std)
# Out:
# 12.231286123404088

# %%
yr1957['lifeExp'].agg(np.sum)
# Out:
# 7314.050959999997

# %%
gm.groupby('continent')['lifeExp'].describe()
# Out:
#            count       mean        std     min       25%      50%       75%  \
# continent
# Africa     624.0  48.865330   9.150210  23.599  42.37250  47.7920  54.41150
# Americas   300.0  64.658737   9.345088  37.579  58.41000  67.0480  71.69950
# Asia       396.0  60.064903  11.864532  28.801  51.42625  61.7915  69.50525
# Europe     360.0  71.903686   5.433178  43.585  69.57000  72.2410  75.45050
# Oceania     24.0  74.326208   3.795611  69.120  71.20500  73.6650  77.55250
#
#               max
# continent
# Africa     76.442
# Americas   80.653
# Asia       82.603
# Europe     81.757
# Oceania    81.235

# %%
gm.groupby('continent')['lifeExp'].agg([np.count_nonzero, np.mean, np.std]).\
    rename(columns={'count_nonzero': 'Counts',
                   'mean': 'Average',
                   'std': 'Standard_deviation'}).\
    reset_index()
# Out:
#   continent  Counts    Average  Standard_deviation
# 0    Africa   624.0  48.865330            9.150210
# 1  Americas   300.0  64.658737            9.345088
# 2      Asia   396.0  60.064903           11.864532
# 3    Europe   360.0  71.903686            5.433178
# 4   Oceania    24.0  74.326208            3.795611

# %%
dir(gm)
# Out:
# ['T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_SLICEMAP',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_wrap__',
#  '__bool__',
#  '__bytes__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__idiv__',
#  '__imul__',
#  '__init__',
#  '__invert__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__nonzero__',
#  '__or__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdiv__',
#  '__reduce__',
# ...
