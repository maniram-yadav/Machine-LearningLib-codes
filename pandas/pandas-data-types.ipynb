# %%
import pandas as pd
import seaborn as sns

# %%
tips = sns.load_dataset('tips')
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
# total_bill    244 non-null float64
# tip           244 non-null float64
# sex           244 non-null category
# smoker        244 non-null category
# day           244 non-null category
# time          244 non-null category
# size          244 non-null int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.2 KB

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
tips['sex_type']=tips['sex'].astype(str)
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size sex_type
# 0         16.99  1.01  Female     No   Sun  Dinner     2   Female
# 1         10.34  1.66    Male     No   Sun  Dinner     3     Male
# 2         21.01  3.50    Male     No   Sun  Dinner     3     Male
# 3         23.68  3.31    Male     No   Sun  Dinner     2     Male
# 4         24.59  3.61  Female     No   Sun  Dinner     4   Female
# 5         25.29  4.71    Male     No   Sun  Dinner     4     Male
# 6          8.77  2.00    Male     No   Sun  Dinner     2     Male
# 7         26.88  3.12    Male     No   Sun  Dinner     4     Male
# 8         15.04  1.96    Male     No   Sun  Dinner     2     Male
# 9         14.78  3.23    Male     No   Sun  Dinner     2     Male
# 10        10.27  1.71    Male     No   Sun  Dinner     2     Male
# 11        35.26  5.00  Female     No   Sun  Dinner     4   Female
# 12        15.42  1.57    Male     No   Sun  Dinner     2     Male
# ...

# %%
tips['pay_bill']=tips['total_bill'].astype(float)
tips
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 9 columns):
# total_bill    244 non-null float64
# tip           244 non-null float64
# sex           244 non-null category
# smoker        244 non-null category
# day           244 non-null category
# time          244 non-null category
# size          244 non-null int64
# sex_type      244 non-null object
# pay_bill      244 non-null float64
# dtypes: category(4), float64(3), int64(1), object(1)
# memory usage: 11.0+ KB

# %%
tips.loc[[1,4,2,9],'pay_bill']='missing'
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size sex_type pay_bill
# 0       16.99  1.01  Female     No  Sun  Dinner     2   Female    16.99
# 1       10.34  1.66    Male     No  Sun  Dinner     3     Male  missing
# 2       21.01  3.50    Male     No  Sun  Dinner     3     Male  missing
# 3       23.68  3.31    Male     No  Sun  Dinner     2     Male    23.68
# 4       24.59  3.61  Female     No  Sun  Dinner     4   Female  missing

# %%
pd.to_numeric(tips['pay_bill'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-0817a2682b2f> in <module>()
# ----> 1 pd.to_numeric(tips['pay_bill'])
#
# C:\Users\maniram\Anaconda2\lib\site-packages\pandas\core\tools\numeric.pyc in to_numeric(arg, errors, downcast)
#     124             coerce_numeric = False if errors in ('ignore', 'raise') else True
#     125             values = lib.maybe_convert_numeric(values, set(),
# --> 126                                                coerce_numeric=coerce_numeric)
#     127
#     128     except Exception:
#
# pandas/_libs/src\inference.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "missing" at position 1

# %%
tips['pay_bill'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-d41124f9fe4b> in <module>()
# ----> 1 tips['pay_bill'].astype(float)
#
# C:\Users\maniram\Anaconda2\lib\site-packages\pandas\util\_decorators.pyc in wrapper(*args, **kwargs)
#      89                 else:
#      90                     kwargs[new_arg_name] = new_arg_value
# ---> 91             return func(*args, **kwargs)
#      92         return wrapper
#      93     return _deprecate_kwarg
#
# C:\Users\maniram\Anaconda2\lib\site-packages\pandas\core\generic.pyc in astype(self, dtype, copy, errors, **kwargs)
#    3408         # else, only a single dtype is given
#    3409         new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 3410                                      **kwargs)
#    3411         return self._constructor(new_data).__finalize__(self)
#    3412
#
# ...

# %%
pd.to_numeric(tips['pay_bill'],errors='ignore').head()
# Out:
# 0      16.99
# 1    missing
# 2    missing
# 3      23.68
# 4    missing
# Name: pay_bill, dtype: object

# %%
tips=pd.to_numeric(tips['pay_bill'],errors='coerce')

# %%
tips.head()
# Out:
# 0    16.99
# 1      NaN
# 2      NaN
# 3    23.68
# 4      NaN
# Name: pay_bill, dtype: float64

# %%
tips=pd.DataFrame(tips.fillna(method='ffill').head())

# %%
tips
# Out:
#    pay_bill
# 0     16.99
# 1     16.99
# 2     16.99
# 3     23.68
# 4     23.68

# %%
s=len(tips['pay_bill'])
print tips['pay_bill'].sum()/s
print tips['pay_bill'].mean()
# Out:
# 19.666
# 19.666
